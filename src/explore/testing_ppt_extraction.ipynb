# %%
from extraction.pptx.pipeline import
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from extraction.pptx.pipeline import extract_slide, extract_pptx
#
# ModuleNotFoundError: No module named 'extraction'

# %%
pptx_path ="/Users/rohit/Documents/Git/Enterprise_RAG_Pipeline/data/raw"

# %%
content = extract_pptx(pptx_path)
print(content)
